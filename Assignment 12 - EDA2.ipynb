# %% [markdown]
# # 1. Data Exploration and Preprocessing:

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
data = pd.read_csv(r"D:\Assignments Data Science ExcelR\EDA2\EDA2\adult_with_headers.csv")

# %%
data
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
data.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
# Apply scaling techniques
numeric_features = ['age' , 'fnlwgt' , 'education_num' , 'capital_gain' , 'capital_loss' , 'hours_per_week']

# %%
# Standard Scaling
standard_scaler = StandardScaler()
data_standard_scaled = data.copy()
data_standard_scaled[numeric_features] = standard_scaler.fit_transform(data[numeric_features])

# %%
# Min-Max Scaling
min_max_scaler = MinMaxScaler()
data_min_max_scaled = data.copy()
data_min_max_scaled[numeric_features] = min_max_scaler.fit_transform(data[numeric_features])

# %%
# Display the scaled data
data_standard_scaled.head()
data_min_max_scaled.head()
# Out:
#         age          workclass    fnlwgt   education  education_num  \
# 0  0.301370          State-gov  0.044302   Bachelors       0.800000
# 1  0.452055   Self-emp-not-inc  0.048238   Bachelors       0.800000
# 2  0.287671            Private  0.138113     HS-grad       0.533333
# 3  0.493151            Private  0.151068        11th       0.400000
# 4  0.150685            Private  0.221488   Bachelors       0.800000
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# ...

# %% [markdown]
# # 2. Encoding Techniques

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
# Identify categorical features
categorical_features = data.select_dtypes(include=['object']).columns.tolist()
categorical_features.remove('income')  # Remove target variable if it is categorical

# %%
# Apply One-Hot Encoding to categorical variables with less than 5 categories
one_hot_encoder = OneHotEncoder(drop='first', sparse=False)
one_hot_features = ['sex', 'race', 'relationship']

# %%
# Apply Label Encoding to categorical variables with more than 5 categories
label_encoder = LabelEncoder()
label_encoded_features = ['workclass', 'education', 'marital_status', 'occupation', 'native_country']

# %%
# Create copies of the dataset for encoding
data_one_hot_encoded = data.copy()
data_label_encoded = data.copy()

# %%
# One-Hot Encoding
data_one_hot_encoded = pd.get_dummies(data_one_hot_encoded, columns=one_hot_features, drop_first=True)

# %%
# Label Encoding
for feature in label_encoded_features:
    data_label_encoded[feature] = label_encoder.fit_transform(data_label_encoded[feature])

# %%
# Display the encoded data
data_one_hot_encoded.head()
data_label_encoded.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    occupation    relationship    race      sex  capital_gain  capital_loss  \
# 0           1   Not-in-family   White     Male          2174             0
# 1           4         Husband   White     Male             0             0
# 2           6   Not-in-family   White     Male             0             0
# 3           6         Husband   Black     Male             0             0
# 4          10            Wife   Black   Female             0             0
#
#    hours_per_week  native_country  income
# 0              40              39   <=50K
# ...

# %% [markdown]
# # 3. Feature Engineering

# %%
import numpy as np

# %%
# Create new features
data_engineered = data.copy()

# %%
# Feature 1: Age Group (binned age into categories)
bins = [0, 18, 30, 40, 50, 60, np.inf]
labels = ['0-17', '18-29', '30-39', '40-49', '50-59', '60+']
data_engineered['age_group'] = pd.cut(data_engineered['age'], bins=bins, labels=labels, right=False)

# %%
# Feature 2: Capital Gain to Loss Ratio
data_engineered['capital_gain_loss_ratio'] = data_engineered['capital_gain'] / (data_engineered['capital_loss'] + 1)  # Added 1 to avoid division by zero

# %%
# Apply a transformation to a skewed numerical feature
# Checking skewness
skewness = data_engineered['capital_gain'].skew()
print(f"Skewness of 'capital_gain': {skewness}")
# Out:
# Skewness of 'capital_gain': 11.953847687699799

# %%
# Apply log transformation
data_engineered['capital_gain_log'] = np.log1p(data_engineered['capital_gain'])  # log1p is used to handle zero values

# %%
data_engineered.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income  \
# ...

# %% [markdown]
# # 4. Feature Selection:

# %%
from sklearn.ensemble import IsolationForest

# %%
# Using Isolation Forest to identify outliers
iso_forest = IsolationForest(contamination=0.05, random_state=42)  # Adjust contamination based on dataset
data_engineered['outlier'] = iso_forest.fit_predict(data_engineered[numeric_features])

# %%
# Removing outliers
data_no_outliers = data_engineered[data_engineered['outlier'] == 1].drop(columns=['outlier'])

# %%
data_engineered.shape
# Out:
# (32561, 19)

# %%
data_no_outliers.shape
# Out:
# (30933, 18)

# %% [markdown]
# Discussion on Outliers:
#
# Outliers can significantly affect model performance by:
#
# Biasing the Model: Outliers can skew the distribution of the data, leading to biased model parameters.
#
# Reducing Model Accuracy: The presence of outliers can lead to overfitting, where the model performs well on training data but poorly on unseen data.
#
# Impact on Metrics: Metrics such as mean squared error (MSE) and R-squared can be heavily influenced by outliers, leading to misleading evaluations of model performance.

# %%
#APPLYING PPS

# %%
# !pip install -U ppscore
# Out:
# ...
#   Created wheel for ppscore: filename=ppscore-1.3.0-py2.py3-none-any.whl size=13150 sha256=2e5fe099652cc2c1a46029bfd2073b76f9ffb5f7a68bf050bb6c626900aa4fc8
#   Stored in directory: c:\users\prapanj k m\appdata\local\pip\cache\wheels\5c\80\75\b631985b161d4a29cc0cf94b5f64b00be6297b0968ff1337ce
# Successfully built ppscore
# ...

# %%
import ppscore as pps
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Calculate the PPS matrix
pps_matrix = pps.matrix(data_no_outliers)
pps_matrix = pps_matrix.pivot("x", "y", "ppscore")
# Out:
# C:\Users\PRAPANJ K M\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\PRAPANJ K M\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\PRAPANJ K M\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\PRAPANJ K M\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# ...

# %%
# Visualize the PPS matrix
plt.figure(figsize=(15,15))
sns.heatmap(pps_matrix, annot=True, cmap="coolwarm", center=0)
plt.title('Predictive Power Score Matrix')
plt.show()

# %%
# Compare with correlation matrix
correlation_matrix = data_no_outliers.corr()

# %%
correlation_matrix
# Out:
#                               age    fnlwgt  education_num  capital_gain  \
# age                      1.000000 -0.079026       0.035963      0.093410
# fnlwgt                  -0.079026  1.000000      -0.039355     -0.012993
# education_num            0.035963 -0.039355       1.000000      0.130080
# capital_gain             0.093410 -0.012993       0.130080      1.000000
# capital_loss             0.029835 -0.011045       0.045779     -0.032021
# hours_per_week           0.094233 -0.021354       0.134755      0.082962
# capital_gain_loss_ratio  0.093410 -0.012993       0.130080      1.000000
# capital_gain_log         0.096498 -0.014575       0.098761      0.868804
#
#                          capital_loss  hours_per_week  \
# age                          0.029835        0.094233
# fnlwgt                      -0.011045       -0.021354
# education_num                0.045779        0.134755
# capital_gain                -0.032021        0.082962
# ...

# %%
# Visualize the correlation matrix
plt.figure(figsize=(15,15))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", center=0)
plt.title('Correlation Matrix')
plt.show()
